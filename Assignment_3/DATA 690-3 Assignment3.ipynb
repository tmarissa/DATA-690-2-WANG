# %%
import random
randomlist = []
for i in range(100):
    n = random.randint(0,9)
    randomlist.append(n)
            
randomlist
# Out:
# [8,
#  1,
#  3,
#  4,
#  9,
#  6,
#  4,
#  0,
#  3,
#  8,
#  0,
#  6,
#  0,
#  3,
#  4,
#  4,
#  7,
#  5,
#  3,
#  8,
#  9,
#  8,
#  9,
#  0,
#  0,
#  8,
#  5,
#  8,
#  6,
#  3,
#  7,
#  0,
#  2,
#  3,
#  9,
#  3,
#  9,
#  5,
#  8,
#  4,
#  7,
#  4,
#  5,
#  1,
#  3,
#  2,
#  0,
#  8,
#  0,
#  7,
#  1,
#  7,
#  2,
#  7,
#  5,
#  9,
#  3,
#  3,
#  4,
#  5,
#  4,
#  4,
#  5,
#  1,
#  0,
#  8,
#  0,
#  6,
#  3,
#  2,
#  2,
#  6,
#  9,
#  0,
#  9,
#  1,
#  9,
#  9,
#  1,
#  0,
#  6,
#  2,
#  3,
#  2,
#  1,
#  1,
#  6,
#  0,
#  8,
#  0,
#  3,
#  1,
#  7,
#  4,
#  6,
#  5,
#  3,
#  5,
#  0,
#  1]

# %%
randomlist = []
for x in range(10):
    row = []
    for y in range(10):
        n = random.randint(0,9)
        row.append(n)
    randomlist.append(row)  

randomlist
# Out:
# [[4, 3, 7, 4, 7, 7, 8, 2, 3, 1],
#  [0, 9, 0, 8, 6, 4, 4, 2, 8, 9],
#  [1, 7, 7, 6, 4, 7, 4, 3, 7, 5],
#  [6, 1, 3, 1, 7, 1, 5, 8, 6, 6],
#  [4, 2, 1, 8, 5, 9, 9, 3, 5, 1],
#  [5, 7, 4, 6, 2, 5, 3, 9, 3, 0],
#  [6, 1, 9, 1, 5, 6, 9, 0, 5, 9],
#  [8, 5, 6, 4, 9, 8, 5, 2, 8, 8],
#  [2, 2, 3, 4, 5, 0, 2, 7, 0, 2],
#  [3, 2, 4, 0, 8, 5, 5, 0, 3, 2]]

# %%
randomlist = []
for x in range(10):
    row = []
    for y in range(10):
        n = random.randint(0,9)
        n_int = int(n)
        if n%2 == 0:
            row.append(n_int)
        else:
            row.append('@')
    randomlist.append(row)  
randomlist
# Out:
# [['@', '@', '@', 6, '@', 4, '@', '@', '@', '@'],
#  [0, 4, '@', 2, 4, '@', 2, '@', 8, 2],
#  ['@', '@', '@', 2, '@', 2, 0, '@', '@', 8],
#  [4, '@', '@', 2, 0, '@', 6, '@', '@', '@'],
#  ['@', 6, 6, 2, 0, '@', '@', '@', 4, 6],
#  ['@', 6, '@', '@', '@', 6, '@', 2, 4, '@'],
#  ['@', '@', '@', '@', '@', 0, 8, 8, 6, 4],
#  ['@', '@', '@', '@', 4, '@', '@', 8, 2, '@'],
#  ['@', 8, '@', 4, '@', 6, '@', 6, 2, 8],
#  [2, '@', '@', 6, '@', '@', 0, '@', 0, '@']]

# %%
randomlist = []

for x in range(10):
    row = []
    total = 0
    for y in range(10):
        n = random.randint(0,9)
        
        row.append(n)
        total += n    
                 
    print(row, " * ", total)
    
    randomlist.append(row)
# Out:
# [7, 4, 9, 3, 2, 7, 0, 6, 1, 6]  *  45
# [4, 0, 0, 2, 4, 6, 4, 9, 0, 4]  *  33
# [2, 8, 2, 9, 6, 0, 4, 6, 9, 3]  *  49
# [9, 2, 6, 8, 8, 4, 1, 0, 8, 7]  *  53
# [1, 4, 6, 6, 1, 3, 7, 6, 0, 1]  *  35
# [9, 4, 5, 5, 4, 2, 7, 7, 1, 6]  *  50
# [7, 1, 5, 7, 5, 7, 2, 3, 7, 1]  *  45
# [3, 8, 5, 6, 8, 3, 4, 7, 6, 4]  *  54
# [7, 5, 7, 1, 4, 7, 3, 3, 8, 5]  *  50
# [3, 7, 9, 0, 8, 8, 2, 4, 2, 4]  *  47

# %%
a = []
total = 0

num_stars = 34
num_printed = 0

while num_printed < num_stars:
    print('*', end = '')
    num_printed += 1

print(' ')

for x in range(10):
    row = []
    for y in range(10):
        n = random.randint(0,9)
        row.append(n)

    print("*", row, "*")
    #a.append(row)

num_stars = 34
num_printed = 0

while num_printed < num_stars:
    print('*', end = '')
    num_printed += 1
# Out:
# **********************************
# * [1, 2, 8, 8, 4, 9, 9, 4, 2, 2] *
# * [7, 8, 2, 1, 4, 2, 0, 0, 6, 8] *
# * [6, 0, 6, 4, 4, 2, 8, 6, 6, 8] *
# * [7, 7, 0, 3, 0, 6, 2, 5, 9, 7] *
# * [5, 6, 2, 8, 7, 0, 2, 5, 8, 0] *
# * [2, 9, 0, 7, 3, 6, 6, 4, 3, 1] *
# * [4, 3, 8, 6, 6, 7, 9, 9, 0, 7] *
# * [7, 1, 4, 0, 4, 8, 0, 2, 8, 2] *
# * [6, 8, 2, 0, 1, 3, 7, 2, 9, 2] *
# * [3, 3, 9, 9, 9, 5, 8, 0, 5, 8] *
# **********************************

# %%
a = []
total1 = 0


for x in range(12):
    row = []
    total = 0
    total1 += n

    for y in range(10):
        
        n = random.randint(0,9)
        row.append(n)
        total += n

    print(row, "*", total)

        
print("*")
print(total1)
# Out:
# [1, 7, 2, 5, 4, 6, 2, 4, 9, 9] * 49
# [7, 3, 5, 9, 0, 5, 7, 8, 7, 1] * 52
# [2, 3, 7, 3, 9, 1, 6, 9, 0, 1] * 41
# [9, 1, 0, 5, 5, 3, 4, 0, 4, 2] * 33
# [5, 1, 4, 1, 1, 9, 6, 7, 4, 8] * 46
# [5, 9, 7, 1, 4, 4, 1, 5, 4, 5] * 45
# [0, 2, 3, 5, 1, 4, 9, 3, 5, 1] * 33
# [8, 4, 6, 0, 0, 6, 6, 4, 7, 1] * 42
# [8, 1, 6, 5, 3, 1, 2, 1, 9, 7] * 43
# [7, 5, 8, 2, 5, 7, 6, 9, 3, 2] * 54
# [1, 7, 2, 8, 5, 8, 9, 7, 8, 3] * 58
# [6, 8, 8, 5, 4, 6, 8, 2, 3, 2] * 52
# *
# 48

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b5cd74e3-7101-44d8-85b7-4ba52680bee7' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
